# %%
EXP_NAME = "EXP_0_1"
MODEL_NAME = "CNN"

# %%
import torch; torch.manual_seed(0)
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.utils.data import DataLoader,random_split, ConcatDataset
from function.Dir import Dir
from function.ssim_torch import ssim_function
from function.jsdiv import jsdiv 
from function.Dataset import ImageDataset
from function.Loss import Custom_criterion
from function.Log import log
import torch.nn.functional as F
import importlib


VAE_module = importlib.import_module('function.%s_%s'%(MODEL_NAME,EXP_NAME))
VAE = getattr(VAE_module, MODEL_NAME)

filepath = "../SimulatedData/norandPSF_6.4x6.4.npy"
#补充数据集，可以选择tx的数据集一块训练
supplementpath = "../SimulatedData/pointsrctest.npy"

#filepath = "../SimulatedData/GaussianSRC_tx.npy"
traintype='src+pointsrc'
filetmp = np.load(filepath,allow_pickle=True)
filelen = filetmp.shape[0]
del filetmp
print(filelen)
frac_train = 0.8
NUM_TO_LEARN = int(filelen)

filetmp = np.load(supplementpath,allow_pickle=True)
supplen = filetmp.shape[0]
del filetmp
print(supplen)
NUM_SUPP = int(supplen)


EPOCHS = 500 #参数1
BATCH_SIZE = 32 #参数2
LATENTDIM = 64 #参数3
LR_MAX = 5e-4
LR_MIN = 5e-6
mode = 1 #0代表STED_HC文件训练，1代表使用STED，对应ImageDataset里的 mode 参数。（STED出的模型对泛化能力弱，STED_HC对训练集的还原会有点失真）

DEVICE = 'cuda'
LOSS_PLOT = []
TESTLOSS_PLOT = []
EPOCH_PLOT = []
# Out:
# 25200
# 400

# %%
name = f'{EPOCHS}epo_{BATCH_SIZE}bth_{LATENTDIM}latn_{traintype}'

#加载数据集
'''生成数据集，注意种子要保存好，不然测试无法复现测试集。'''
dataset = ImageDataset(NUM_TO_LEARN, mode,filepath)
supplementset = ImageDataset(NUM_SUPP,mode,supplementpath)

trainset, testset = random_split(dataset,
                                            lengths=[int(frac_train *len(dataset)),
                                            len(dataset) - int(frac_train * len(dataset))],
                                            generator=torch.Generator().manual_seed(0))
trainset = ConcatDataset([trainset,supplementset])

dataloader = DataLoader(trainset,shuffle=True,batch_size=BATCH_SIZE)
testloader = DataLoader(testset,shuffle=True,batch_size=BATCH_SIZE)
#初始化VAE网络
vae = VAE(LATENTDIM).to(DEVICE)
#vae.reset_parameters()
#vae = nn.DataParallel(vae) #将 VAE 包装成一个并行化模型，以便在多个 GPU 上并行地进行训练

#定义LOSS函数与优化器
#criterion1 = jsdiv#ssim_function#nn.MSELoss()
#criterion2 = jsdiv#ssim_function#Custom_criterion().cuda()
lossfunction = jsdiv#ssim_function
optimizer = torch.optim.AdamW(vae.parameters(), lr = LR_MAX)

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    continue
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")
blurry_img_numpy = blurry_img[1].squeeze().detach().numpy()
print(blurry_img_numpy.min())
print(blurry_img_numpy.max())
print(blurry_img_numpy)
# Out:
# 0.0
# 1.0
# [[0.49898615 0.5100756  0.52215564 ... 0.72008926 0.74201214 0.7684235 ]
#  [0.46369913 0.47526702 0.48745558 ... 0.7173309  0.7349914  0.7533656 ]
#  [0.43004856 0.44250163 0.45507196 ... 0.7078686  0.71939296 0.7278039 ]
#  ...
#  [0.6672936  0.6585139  0.6492486  ... 0.34577286 0.36856186 0.3978936 ]
#  [0.66973466 0.6600428  0.6486171  ... 0.35283127 0.3707157  0.39347926]
#  [0.6756519  0.66543484 0.65211266 ... 0.35445288 0.3655973  0.38026625]]

# %%
# 打印数据集中的一些样本
for batch_idx, (blurry_img, original_img) in enumerate(dataloader):
    continue
    print(f"Batch {batch_idx + 1}:")
    print(f"Blurry image shape: {blurry_img.shape}")
    print(f"Original image shape: {original_img.shape}")

num_images_to_show = 5
# 创建一个包含两列的图像网格，每一列显示一张模糊图像和一张原始图像
fig, axes = plt.subplots(num_images_to_show, 2, figsize=(10, 2*num_images_to_show))
# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像和原始图像
    blurry_img_numpy = blurry_img[i].squeeze().detach().numpy()
    original_img_numpy = original_img[i].squeeze().detach().numpy()
    
    # 显示模糊图像
    axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')
    
    # 显示原始图像
    axes[i, 1].imshow(original_img_numpy)
    axes[i, 1].set_title('Original Image')
    axes[i, 1].axis('off')

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()

# %%
def train(dataloader, num_epochs):
    with open(f'training.log', 'w') as nothing: # 清空原log
        pass
    log(f"Experiment name: {EXP_NAME}")
    for epoch in range(num_epochs):
        vae.train() # 切换成训练模式
        total_loss = 0.0
        current_lr = LR_MIN + 0.5 * (LR_MAX - LR_MIN) * (1 + np.cos(np.pi * epoch / EPOCHS))
        optimizer = torch.optim.AdamW(vae.parameters(), lr = current_lr)

        for _, (img_LR, img_HR) in enumerate(dataloader):
            # img_LR = torch.squeeze(img_LR,dim = 1).to(DEVICE)
            # img_HR = torch.squeeze(img_HR,dim = 1).to(DEVICE)
            img_LR = img_LR.to(DEVICE)
            img_HR = img_HR.to(DEVICE)
            img_SR, _, _ = vae(img_LR)
            img_SR = img_SR.to(DEVICE)
            # 这步为止，img_LR,img_HR,img_SR均是[batchsize,不知道是什么,宽，高]
            #if epoch <= 500:
            #    loss = criterion1(img_SR, img_HR)
            #if epoch > 500:
            #    loss = criterion2(img_SR, img_HR) # 每个BATCH的loss，64张图平均
            loss = lossfunction(img_SR,img_HR)
            optimizer.zero_grad()
            loss.backward() # 最耗算力的一步
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader) # 每个EPOCH的loss，全部数据集的平均

        test_loss = 0.0
        for _, (img_LR, img_HR) in enumerate(testloader):
            # img_LR = torch.squeeze(img_LR,dim = 1).to(DEVICE)
            # img_HR = torch.squeeze(img_HR,dim = 1).to(DEVICE)
            img_LR = img_LR.to(DEVICE)
            img_HR = img_HR.to(DEVICE)
            img_SR, _, _ = vae(img_LR)
            img_SR = img_SR.to(DEVICE)
            # 这步为止，img_LR,img_HR,img_SR均是[batchsize,不知道是什么,宽，高]
            #if epoch <= 500:
            #    loss = criterion1(img_SR, img_HR)
            #if epoch > 500:
            #    loss = criterion2(img_SR, img_HR) # 每个BATCH的loss，64张图平均
            loss = lossfunction(img_SR,img_HR)
            test_loss += loss.item()
        test_avg_loss = test_loss / len(testloader)

        
        print(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4e}, Test Loss: {test_avg_loss:.4e}, Current_LR:{current_lr:.4f}")
        log(f"Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4e}, Test Loss: {test_avg_loss:.4e}, Current_LR:{current_lr:.4f}")

        LOSS_PLOT.append(avg_loss)
        TESTLOSS_PLOT.append(test_avg_loss)
        EPOCH_PLOT.append(epoch)
        # if epoch % 300 == 0:
        #     torch.save(vae.state_dict(), Dir.TEMP()+'/checkpoint.pth')

# %%
# for _, (img_LR, img_HR) in enumerate(dataloader):
#     img_SR, _, _ = vae(img_LR)
#     img_SR = img_SR.to(DEVICE)
#     print(img_SR.max())

# %%
datas = np.load(filepath,allow_pickle=True)#.astype(np.object)
blurry_datas = np.stack(datas[:,1])
original_datas = np.stack(datas[:,0])

# %%
    
torch.set_printoptions(precision=10)
#lossfunction = ssim_function
print(f'DEVICE:{DEVICE}\n')
print(f'Training Start. \nExperiment name: {EXP_NAME}')
train(dataloader, EPOCHS)
print(f'\n Succsessfully done! Training log saved.')
# Out:
# DEVICE:cuda
#
# Training Start.
# Experiment name: EXP_0_1
# Epoch [1/500], Average Loss: 4.7825e-04, Test Loss: 2.1128e-04, Current_LR:0.0005
# Epoch [2/500], Average Loss: 1.9372e-04, Test Loss: 1.6118e-04, Current_LR:0.0005
# Epoch [3/500], Average Loss: 1.7726e-04, Test Loss: 2.5066e-04, Current_LR:0.0005
# Epoch [4/500], Average Loss: 1.6046e-04, Test Loss: 1.4033e-04, Current_LR:0.0005
# Epoch [5/500], Average Loss: 1.5107e-04, Test Loss: 1.8420e-04, Current_LR:0.0005
# Epoch [6/500], Average Loss: 1.4588e-04, Test Loss: 1.3545e-04, Current_LR:0.0005
# Epoch [7/500], Average Loss: 1.3934e-04, Test Loss: 1.4750e-04, Current_LR:0.0005
# Epoch [8/500], Average Loss: 1.3621e-04, Test Loss: 1.3241e-04, Current_LR:0.0005
# Epoch [9/500], Average Loss: 1.3264e-04, Test Loss: 1.4372e-04, Current_LR:0.0005
# Epoch [10/500], Average Loss: 1.3341e-04, Test Loss: 1.3856e-04, Current_LR:0.0005
# Epoch [11/500], Average Loss: 1.2697e-04, Test Loss: 1.2186e-04, Current_LR:0.0005
# Epoch [12/500], Average Loss: 1.2949e-04, Test Loss: 1.5571e-04, Current_LR:0.0005
# Epoch [13/500], Average Loss: 1.2718e-04, Test Loss: 1.4385e-04, Current_LR:0.0005
# Epoch [44/500], Average Loss: 1.0597e-04, Test Loss: 1.2569e-04, Current_LR:0.0005
# Epoch [45/500], Average Loss: 1.0574e-04, Test Loss: 1.0183e-04, Current_LR:0.0005
# Epoch [46/500], Average Loss: 1.0519e-04, Test Loss: 1.2599e-04, Current_LR:0.0005
# Epoch [47/500], Average Loss: 1.0466e-04, Test Loss: 1.0304e-04, Current_LR:0.0005
# Epoch [48/500], Average Loss: 1.0481e-04, Test Loss: 1.0420e-04, Current_LR:0.0005
# Epoch [49/500], Average Loss: 1.0499e-04, Test Loss: 1.0729e-04, Current_LR:0.0005
# Epoch [50/500], Average Loss: 1.0531e-04, Test Loss: 1.0615e-04, Current_LR:0.0005
# Epoch [51/500], Average Loss: 1.0415e-04, Test Loss: 1.0950e-04, Current_LR:0.0005
# Epoch [52/500], Average Loss: 1.0449e-04, Test Loss: 1.0712e-04, Current_LR:0.0005
# Epoch [53/500], Average Loss: 1.0388e-04, Test Loss: 1.0275e-04, Current_LR:0.0005
# Epoch [54/500], Average Loss: 1.0461e-04, Test Loss: 1.0702e-04, Current_LR:0.0005
# Epoch [55/500], Average Loss: 1.0342e-04, Test Loss: 1.1045e-04, Current_LR:0.0005
# Epoch [56/500], Average Loss: 1.0298e-04, Test Loss: 1.0440e-04, Current_LR:0.0005
# Epoch [57/500], Average Loss: 1.0250e-04, Test Loss: 1.0559e-04, Current_LR:0.0005
# Epoch [58/500], Average Loss: 1.0287e-04, Test Loss: 1.0199e-04, Current_LR:0.0005
# Epoch [59/500], Average Loss: 1.0145e-04, Test Loss: 1.0151e-04, Current_LR:0.0005
# Epoch [60/500], Average Loss: 1.0210e-04, Test Loss: 1.2009e-04, Current_LR:0.0005
# Epoch [61/500], Average Loss: 1.0263e-04, Test Loss: 1.0333e-04, Current_LR:0.0005
# Epoch [62/500], Average Loss: 1.0149e-04, Test Loss: 1.2725e-04, Current_LR:0.0005
# Epoch [63/500], Average Loss: 1.0143e-04, Test Loss: 1.0083e-04, Current_LR:0.0005
# Epoch [64/500], Average Loss: 1.0097e-04, Test Loss: 1.0176e-04, Current_LR:0.0005
# Epoch [65/500], Average Loss: 9.9887e-05, Test Loss: 1.0070e-04, Current_LR:0.0005
# Epoch [66/500], Average Loss: 1.0059e-04, Test Loss: 1.0099e-04, Current_LR:0.0005
# Epoch [67/500], Average Loss: 1.0038e-04, Test Loss: 9.8781e-05, Current_LR:0.0005
# Epoch [68/500], Average Loss: 1.0076e-04, Test Loss: 1.0152e-04, Current_LR:0.0005
# Epoch [69/500], Average Loss: 1.0013e-04, Test Loss: 1.0013e-04, Current_LR:0.0005
# Epoch [70/500], Average Loss: 1.0017e-04, Test Loss: 1.0786e-04, Current_LR:0.0005
# Epoch [71/500], Average Loss: 9.9428e-05, Test Loss: 9.8788e-05, Current_LR:0.0005
# Epoch [72/500], Average Loss: 9.9735e-05, Test Loss: 1.0140e-04, Current_LR:0.0005
# Epoch [73/500], Average Loss: 9.9243e-05, Test Loss: 1.0036e-04, Current_LR:0.0005
# Epoch [192/500], Average Loss: 8.8823e-05, Test Loss: 9.3660e-05, Current_LR:0.0003
# Epoch [193/500], Average Loss: 8.8707e-05, Test Loss: 1.0103e-04, Current_LR:0.0003
# Epoch [194/500], Average Loss: 8.8408e-05, Test Loss: 9.0348e-05, Current_LR:0.0003
# Epoch [195/500], Average Loss: 8.8738e-05, Test Loss: 9.3054e-05, Current_LR:0.0003
# Epoch [196/500], Average Loss: 8.9499e-05, Test Loss: 9.1491e-05, Current_LR:0.0003
# Epoch [197/500], Average Loss: 8.9216e-05, Test Loss: 1.0259e-04, Current_LR:0.0003
# Epoch [198/500], Average Loss: 8.8772e-05, Test Loss: 9.0905e-05, Current_LR:0.0003
# Epoch [199/500], Average Loss: 8.8506e-05, Test Loss: 1.0030e-04, Current_LR:0.0003
# Epoch [200/500], Average Loss: 8.9163e-05, Test Loss: 9.1667e-05, Current_LR:0.0003
# Epoch [201/500], Average Loss: 8.8326e-05, Test Loss: 9.3189e-05, Current_LR:0.0003
# Epoch [202/500], Average Loss: 8.8259e-05, Test Loss: 1.0509e-04, Current_LR:0.0003
# Epoch [203/500], Average Loss: 8.8379e-05, Test Loss: 8.9823e-05, Current_LR:0.0003
# Epoch [204/500], Average Loss: 8.8626e-05, Test Loss: 9.2670e-05, Current_LR:0.0003
# Epoch [205/500], Average Loss: 8.9171e-05, Test Loss: 9.4014e-05, Current_LR:0.0003
# Epoch [206/500], Average Loss: 8.8521e-05, Test Loss: 8.9751e-05, Current_LR:0.0003
# Epoch [207/500], Average Loss: 8.7874e-05, Test Loss: 9.1171e-05, Current_LR:0.0003
# Epoch [208/500], Average Loss: 8.8580e-05, Test Loss: 8.8851e-05, Current_LR:0.0003
# Epoch [209/500], Average Loss: 8.8191e-05, Test Loss: 9.6317e-05, Current_LR:0.0003
# Epoch [210/500], Average Loss: 8.8194e-05, Test Loss: 9.4365e-05, Current_LR:0.0003
# Epoch [211/500], Average Loss: 8.8237e-05, Test Loss: 9.1330e-05, Current_LR:0.0003
# Epoch [212/500], Average Loss: 8.8659e-05, Test Loss: 8.9881e-05, Current_LR:0.0003
# Epoch [213/500], Average Loss: 8.8710e-05, Test Loss: 8.8871e-05, Current_LR:0.0003
# Epoch [214/500], Average Loss: 8.8379e-05, Test Loss: 9.0023e-05, Current_LR:0.0003
# Epoch [215/500], Average Loss: 8.7249e-05, Test Loss: 9.1506e-05, Current_LR:0.0003
# Epoch [216/500], Average Loss: 8.7500e-05, Test Loss: 8.8640e-05, Current_LR:0.0003
# Epoch [217/500], Average Loss: 8.7555e-05, Test Loss: 9.0719e-05, Current_LR:0.0003
# Epoch [218/500], Average Loss: 8.7033e-05, Test Loss: 9.0497e-05, Current_LR:0.0003
# Epoch [219/500], Average Loss: 8.8067e-05, Test Loss: 9.0942e-05, Current_LR:0.0003
# Epoch [220/500], Average Loss: 8.8269e-05, Test Loss: 8.9376e-05, Current_LR:0.0003
# Epoch [221/500], Average Loss: 8.7285e-05, Test Loss: 8.9620e-05, Current_LR:0.0003
# Epoch [222/500], Average Loss: 8.7790e-05, Test Loss: 8.9982e-05, Current_LR:0.0003
# Epoch [223/500], Average Loss: 8.7458e-05, Test Loss: 9.2070e-05, Current_LR:0.0003
# Epoch [224/500], Average Loss: 8.6731e-05, Test Loss: 8.9598e-05, Current_LR:0.0003
# Epoch [225/500], Average Loss: 8.7221e-05, Test Loss: 9.0697e-05, Current_LR:0.0003
# Epoch [226/500], Average Loss: 8.6943e-05, Test Loss: 9.3091e-05, Current_LR:0.0003
# Epoch [227/500], Average Loss: 8.7056e-05, Test Loss: 8.8388e-05, Current_LR:0.0003
# Epoch [228/500], Average Loss: 8.7110e-05, Test Loss: 9.0132e-05, Current_LR:0.0003
# Epoch [229/500], Average Loss: 8.6796e-05, Test Loss: 8.8366e-05, Current_LR:0.0003
# Epoch [230/500], Average Loss: 8.8299e-05, Test Loss: 9.2974e-05, Current_LR:0.0003
# Epoch [231/500], Average Loss: 8.7683e-05, Test Loss: 8.9872e-05, Current_LR:0.0003
# Epoch [232/500], Average Loss: 8.6696e-05, Test Loss: 9.0085e-05, Current_LR:0.0003
# Epoch [233/500], Average Loss: 8.7319e-05, Test Loss: 1.0021e-04, Current_LR:0.0003
# Epoch [234/500], Average Loss: 8.6653e-05, Test Loss: 1.0155e-04, Current_LR:0.0003
# Epoch [235/500], Average Loss: 8.7080e-05, Test Loss: 8.8582e-05, Current_LR:0.0003
# Epoch [236/500], Average Loss: 8.7646e-05, Test Loss: 8.8958e-05, Current_LR:0.0003
# Epoch [237/500], Average Loss: 8.6519e-05, Test Loss: 8.6967e-05, Current_LR:0.0003
# Epoch [238/500], Average Loss: 8.6241e-05, Test Loss: 9.2168e-05, Current_LR:0.0003
# Epoch [239/500], Average Loss: 8.5841e-05, Test Loss: 8.9000e-05, Current_LR:0.0003
# Epoch [240/500], Average Loss: 8.6937e-05, Test Loss: 9.3218e-05, Current_LR:0.0003
# Epoch [241/500], Average Loss: 8.6091e-05, Test Loss: 9.0320e-05, Current_LR:0.0003
# Epoch [242/500], Average Loss: 8.6572e-05, Test Loss: 8.9373e-05, Current_LR:0.0003
# Epoch [243/500], Average Loss: 8.5421e-05, Test Loss: 8.8226e-05, Current_LR:0.0003
# Epoch [244/500], Average Loss: 8.5655e-05, Test Loss: 9.0852e-05, Current_LR:0.0003
# Epoch [245/500], Average Loss: 8.5331e-05, Test Loss: 9.9811e-05, Current_LR:0.0003
# Epoch [246/500], Average Loss: 8.6026e-05, Test Loss: 8.8002e-05, Current_LR:0.0003
# Epoch [247/500], Average Loss: 8.6736e-05, Test Loss: 9.0763e-05, Current_LR:0.0003
# Epoch [248/500], Average Loss: 8.6172e-05, Test Loss: 9.0939e-05, Current_LR:0.0003
# Epoch [249/500], Average Loss: 8.6536e-05, Test Loss: 8.7299e-05, Current_LR:0.0003
# Epoch [250/500], Average Loss: 8.6338e-05, Test Loss: 9.0678e-05, Current_LR:0.0003
# Epoch [251/500], Average Loss: 8.5371e-05, Test Loss: 8.6547e-05, Current_LR:0.0003
# Epoch [252/500], Average Loss: 8.6343e-05, Test Loss: 8.9989e-05, Current_LR:0.0003
# Epoch [253/500], Average Loss: 8.5809e-05, Test Loss: 8.8917e-05, Current_LR:0.0002
# Epoch [254/500], Average Loss: 8.6036e-05, Test Loss: 8.8265e-05, Current_LR:0.0002
# Epoch [255/500], Average Loss: 8.6116e-05, Test Loss: 8.9444e-05, Current_LR:0.0002
# Epoch [256/500], Average Loss: 8.5515e-05, Test Loss: 8.8001e-05, Current_LR:0.0002
# Epoch [257/500], Average Loss: 8.6198e-05, Test Loss: 8.9175e-05, Current_LR:0.0002
# Epoch [258/500], Average Loss: 8.5234e-05, Test Loss: 8.8812e-05, Current_LR:0.0002
# Epoch [259/500], Average Loss: 8.5981e-05, Test Loss: 8.8485e-05, Current_LR:0.0002
# Epoch [260/500], Average Loss: 8.5271e-05, Test Loss: 9.0440e-05, Current_LR:0.0002
# Epoch [261/500], Average Loss: 8.5472e-05, Test Loss: 9.4221e-05, Current_LR:0.0002
# Epoch [262/500], Average Loss: 8.5663e-05, Test Loss: 8.8073e-05, Current_LR:0.0002
# Epoch [263/500], Average Loss: 8.5437e-05, Test Loss: 8.6903e-05, Current_LR:0.0002
# Epoch [264/500], Average Loss: 8.5387e-05, Test Loss: 8.8428e-05, Current_LR:0.0002
# Epoch [265/500], Average Loss: 8.5090e-05, Test Loss: 9.1708e-05, Current_LR:0.0002
# Epoch [266/500], Average Loss: 8.5256e-05, Test Loss: 8.9029e-05, Current_LR:0.0002
# Epoch [267/500], Average Loss: 8.5183e-05, Test Loss: 9.5352e-05, Current_LR:0.0002
# Epoch [268/500], Average Loss: 8.4261e-05, Test Loss: 9.0048e-05, Current_LR:0.0002
# Epoch [269/500], Average Loss: 8.5238e-05, Test Loss: 8.7347e-05, Current_LR:0.0002
# Epoch [270/500], Average Loss: 8.5020e-05, Test Loss: 9.1610e-05, Current_LR:0.0002
# Epoch [271/500], Average Loss: 8.4959e-05, Test Loss: 8.6872e-05, Current_LR:0.0002
# Epoch [272/500], Average Loss: 8.4725e-05, Test Loss: 8.6721e-05, Current_LR:0.0002
# Epoch [273/500], Average Loss: 8.4437e-05, Test Loss: 8.6769e-05, Current_LR:0.0002
# Epoch [274/500], Average Loss: 8.4898e-05, Test Loss: 8.9278e-05, Current_LR:0.0002
# Epoch [275/500], Average Loss: 8.4410e-05, Test Loss: 8.7734e-05, Current_LR:0.0002
# Epoch [276/500], Average Loss: 8.4737e-05, Test Loss: 8.9227e-05, Current_LR:0.0002
# Epoch [277/500], Average Loss: 8.4086e-05, Test Loss: 8.6659e-05, Current_LR:0.0002
# Epoch [278/500], Average Loss: 8.4274e-05, Test Loss: 9.0817e-05, Current_LR:0.0002
# Epoch [279/500], Average Loss: 8.4210e-05, Test Loss: 8.5881e-05, Current_LR:0.0002
# Epoch [280/500], Average Loss: 8.3938e-05, Test Loss: 8.7189e-05, Current_LR:0.0002
# Epoch [281/500], Average Loss: 8.4235e-05, Test Loss: 8.7746e-05, Current_LR:0.0002
# Epoch [282/500], Average Loss: 8.4148e-05, Test Loss: 8.9161e-05, Current_LR:0.0002
# Epoch [283/500], Average Loss: 8.4649e-05, Test Loss: 9.2164e-05, Current_LR:0.0002
# Epoch [284/500], Average Loss: 8.4336e-05, Test Loss: 8.9566e-05, Current_LR:0.0002
# Epoch [285/500], Average Loss: 8.3727e-05, Test Loss: 9.1362e-05, Current_LR:0.0002
# Epoch [286/500], Average Loss: 8.4059e-05, Test Loss: 8.6079e-05, Current_LR:0.0002
# Epoch [287/500], Average Loss: 8.3803e-05, Test Loss: 9.1677e-05, Current_LR:0.0002
# Epoch [288/500], Average Loss: 8.4192e-05, Test Loss: 8.7568e-05, Current_LR:0.0002
# Epoch [289/500], Average Loss: 8.3549e-05, Test Loss: 9.2086e-05, Current_LR:0.0002
# Epoch [290/500], Average Loss: 8.4183e-05, Test Loss: 8.6666e-05, Current_LR:0.0002
# Epoch [291/500], Average Loss: 8.4127e-05, Test Loss: 9.0964e-05, Current_LR:0.0002
# Epoch [292/500], Average Loss: 8.3676e-05, Test Loss: 8.7127e-05, Current_LR:0.0002
# Epoch [293/500], Average Loss: 8.3266e-05, Test Loss: 8.5434e-05, Current_LR:0.0002
# Epoch [294/500], Average Loss: 8.3956e-05, Test Loss: 9.5490e-05, Current_LR:0.0002
# Epoch [295/500], Average Loss: 8.3843e-05, Test Loss: 9.0018e-05, Current_LR:0.0002
# Epoch [296/500], Average Loss: 8.3585e-05, Test Loss: 8.7208e-05, Current_LR:0.0002
# Epoch [297/500], Average Loss: 8.4242e-05, Test Loss: 8.8668e-05, Current_LR:0.0002
# Epoch [298/500], Average Loss: 8.3934e-05, Test Loss: 8.5266e-05, Current_LR:0.0002
# Epoch [299/500], Average Loss: 8.3442e-05, Test Loss: 8.5534e-05, Current_LR:0.0002
# Epoch [300/500], Average Loss: 8.3402e-05, Test Loss: 8.7097e-05, Current_LR:0.0002
# Epoch [301/500], Average Loss: 8.3335e-05, Test Loss: 9.2172e-05, Current_LR:0.0002
# Epoch [302/500], Average Loss: 8.3340e-05, Test Loss: 8.6215e-05, Current_LR:0.0002
# Epoch [303/500], Average Loss: 8.2960e-05, Test Loss: 8.6622e-05, Current_LR:0.0002
# Epoch [304/500], Average Loss: 8.3527e-05, Test Loss: 8.5295e-05, Current_LR:0.0002
# Epoch [305/500], Average Loss: 8.3302e-05, Test Loss: 8.9021e-05, Current_LR:0.0002
# Epoch [306/500], Average Loss: 8.3138e-05, Test Loss: 8.9091e-05, Current_LR:0.0002
# Epoch [307/500], Average Loss: 8.3047e-05, Test Loss: 8.4916e-05, Current_LR:0.0002
# Epoch [308/500], Average Loss: 8.3442e-05, Test Loss: 8.6544e-05, Current_LR:0.0002
# Epoch [309/500], Average Loss: 8.2716e-05, Test Loss: 8.5582e-05, Current_LR:0.0002
# Epoch [310/500], Average Loss: 8.2911e-05, Test Loss: 8.6362e-05, Current_LR:0.0002
# Epoch [311/500], Average Loss: 8.2664e-05, Test Loss: 8.5680e-05, Current_LR:0.0002
# Epoch [312/500], Average Loss: 8.2587e-05, Test Loss: 8.6644e-05, Current_LR:0.0002
# Epoch [313/500], Average Loss: 8.2863e-05, Test Loss: 8.6648e-05, Current_LR:0.0002
# Epoch [314/500], Average Loss: 8.3003e-05, Test Loss: 8.7074e-05, Current_LR:0.0002
# Epoch [315/500], Average Loss: 8.2906e-05, Test Loss: 8.5342e-05, Current_LR:0.0002
# Epoch [316/500], Average Loss: 8.2674e-05, Test Loss: 8.8603e-05, Current_LR:0.0002
# Epoch [317/500], Average Loss: 8.2941e-05, Test Loss: 8.8451e-05, Current_LR:0.0002
# Epoch [318/500], Average Loss: 8.2206e-05, Test Loss: 8.5132e-05, Current_LR:0.0002
# Epoch [319/500], Average Loss: 8.2469e-05, Test Loss: 8.6085e-05, Current_LR:0.0001
# Epoch [320/500], Average Loss: 8.2158e-05, Test Loss: 8.5409e-05, Current_LR:0.0001
# Epoch [321/500], Average Loss: 8.2283e-05, Test Loss: 8.5035e-05, Current_LR:0.0001
# Epoch [322/500], Average Loss: 8.2885e-05, Test Loss: 8.6118e-05, Current_LR:0.0001
# Epoch [323/500], Average Loss: 8.2388e-05, Test Loss: 8.5320e-05, Current_LR:0.0001
# Epoch [324/500], Average Loss: 8.2162e-05, Test Loss: 8.5592e-05, Current_LR:0.0001
# Epoch [325/500], Average Loss: 8.1774e-05, Test Loss: 8.6952e-05, Current_LR:0.0001
# Epoch [326/500], Average Loss: 8.2443e-05, Test Loss: 8.7917e-05, Current_LR:0.0001
# Epoch [327/500], Average Loss: 8.1996e-05, Test Loss: 8.6164e-05, Current_LR:0.0001
# Epoch [328/500], Average Loss: 8.2031e-05, Test Loss: 8.5535e-05, Current_LR:0.0001
# Epoch [329/500], Average Loss: 8.1881e-05, Test Loss: 8.5452e-05, Current_LR:0.0001
# Epoch [330/500], Average Loss: 8.1756e-05, Test Loss: 8.4946e-05, Current_LR:0.0001
# Epoch [331/500], Average Loss: 8.1985e-05, Test Loss: 8.4468e-05, Current_LR:0.0001
# Epoch [332/500], Average Loss: 8.1867e-05, Test Loss: 8.5417e-05, Current_LR:0.0001
# Epoch [333/500], Average Loss: 8.2321e-05, Test Loss: 8.4558e-05, Current_LR:0.0001
# Epoch [334/500], Average Loss: 8.1846e-05, Test Loss: 8.7614e-05, Current_LR:0.0001
# Epoch [335/500], Average Loss: 8.2081e-05, Test Loss: 8.5538e-05, Current_LR:0.0001
# Epoch [336/500], Average Loss: 8.2272e-05, Test Loss: 8.5184e-05, Current_LR:0.0001
# Epoch [337/500], Average Loss: 8.1686e-05, Test Loss: 8.4815e-05, Current_LR:0.0001
# Epoch [338/500], Average Loss: 8.1706e-05, Test Loss: 8.6586e-05, Current_LR:0.0001
# Epoch [339/500], Average Loss: 8.1673e-05, Test Loss: 8.7158e-05, Current_LR:0.0001
# Epoch [340/500], Average Loss: 8.1203e-05, Test Loss: 8.4690e-05, Current_LR:0.0001
# Epoch [341/500], Average Loss: 8.1369e-05, Test Loss: 8.3954e-05, Current_LR:0.0001
# Epoch [342/500], Average Loss: 8.1356e-05, Test Loss: 8.4530e-05, Current_LR:0.0001
# Epoch [343/500], Average Loss: 8.1509e-05, Test Loss: 8.9520e-05, Current_LR:0.0001
# Epoch [344/500], Average Loss: 8.1512e-05, Test Loss: 8.6360e-05, Current_LR:0.0001
# Epoch [345/500], Average Loss: 8.1384e-05, Test Loss: 8.6678e-05, Current_LR:0.0001
# Epoch [346/500], Average Loss: 8.1187e-05, Test Loss: 8.5420e-05, Current_LR:0.0001
# Epoch [347/500], Average Loss: 8.1289e-05, Test Loss: 8.4075e-05, Current_LR:0.0001
# Epoch [348/500], Average Loss: 8.1320e-05, Test Loss: 8.4403e-05, Current_LR:0.0001
# Epoch [349/500], Average Loss: 8.1134e-05, Test Loss: 9.1527e-05, Current_LR:0.0001
# Epoch [350/500], Average Loss: 8.1196e-05, Test Loss: 8.4376e-05, Current_LR:0.0001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       3 print(f'DEVICE:{DEVICE}\n')
#       4 print(f'Training Start. \nExperiment name: {EXP_NAME}')
# ----> 5 train(dataloader, EPOCHS)
#       6 print(f'\n Succsessfully done! Training log saved.')
#
# Cell In[6], line 24, in train(dataloader, num_epochs)
#      18 # 这步为止，img_LR,img_HR,img_SR均是[batchsize,不知道是什么,宽，高]
#      19 #if epoch <= 500:
#      20 #    loss = criterion1(img_SR, img_HR)
#      21 #if epoch > 500:
#      22 #    loss = criterion2(img_SR, img_HR) # 每个BATCH的loss，64张图平均
#      23 loss = lossfunction(img_SR,img_HR)
# ---> 24 optimizer.zero_grad()
#      25 loss.backward() # 最耗算力的一步
#      26 optimizer.step()
#
# File ~/.torch/lib/python3.12/site-packages/torch/_compile.py:31, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      28     disable_fn = torch._dynamo.disable(fn, recursive)
#      29     fn.__dynamo_disable = disable_fn
# ---> 31 return disable_fn(*args, **kwargs)
#
# File ~/.torch/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:600, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#     598 prior = set_eval_frame(callback)
#     599 try:
# --> 600     return fn(*args, **kwargs)
#     601 finally:
#     602     set_eval_frame(prior)
#
# File ~/.torch/lib/python3.12/site-packages/torch/optim/optimizer.py:947, in Optimizer.zero_grad(self, set_to_none)
#     945 if p.grad is not None:
#     946     if set_to_none:
# --> 947         p.grad = None
#     948     else:
#     949         if p.grad.grad_fn is not None:
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots()
ax.plot(EPOCH_PLOT,LOSS_PLOT)
ax.plot(EPOCH_PLOT,TESTLOSS_PLOT)
ax.set_yscale('log')
fig.savefig(f'../models/{MODEL_NAME}_{EXP_NAME}_lossfig_{name}.png', dpi = 300) # 保存LOSS图片
print(f'LOSS fig saved at {Dir.models()}/{MODEL_NAME}_{EXP_NAME}_lossfig_{name}.png')

LOSS_DATA = np.stack((np.array(EPOCH_PLOT),np.array(LOSS_PLOT),np.array(TESTLOSS_PLOT)),axis=0)
np.save(f'../models/{MODEL_NAME}_{EXP_NAME}_lossdata_{name}.npy',LOSS_DATA) # 保存LOSS数据
print(f'LOSS data saved at {Dir.models()}/{MODEL_NAME}_{EXP_NAME}_lossdata_{name}.npy')

torch.save(vae.state_dict(), f'../models/{MODEL_NAME}_{EXP_NAME}_model_{name}.pth') #保存模型pth
print(f'MODEL saved at {Dir.models()}/{MODEL_NAME}_{EXP_NAME}_model_{name}.pth')
# Out:
# LOSS fig saved at ../outputs/trained_models/CNN_EXP_0_1_lossfig_500epo_32bth_64latn_src+pointsrc.png
# LOSS data saved at ../outputs/trained_models/CNN_EXP_0_1_lossdata_500epo_32bth_64latn_src+pointsrc.npy
# MODEL saved at ../outputs/trained_models/CNN_EXP_0_1_model_500epo_32bth_64latn_src+pointsrc.pth

# %%
import torch
import matplotlib.pyplot as plt

vae.eval()  # 切换到评估模式
vae.to(DEVICE)

for _, (img_LR, img_HR) in enumerate(testloader):
    #print(img_LR.shape)
    img_SR, _, _ = vae(img_LR.to(DEVICE))
    img_SR = img_SR.cpu()

num_images_to_show = 10
# 创建一个包含三列的图像网格，每一列显示一张模糊图像、超分辨率图像和原始图像
fig, axes = plt.subplots(num_images_to_show,5 , figsize=(15, 3 * num_images_to_show))

# 遍历每个样本
for i in range(num_images_to_show):
    # 获取模糊图像、超分辨率图像和原始图像
    blurry_img_numpy = img_LR[i].squeeze().detach().cpu().numpy()
    sr_img_numpy = img_SR[i].squeeze().detach().cpu().numpy()
    original_img_numpy = img_HR[i].squeeze().detach().cpu().numpy()
    
    blurry_img_numpy =blurry_img_numpy/blurry_img_numpy.sum()
    original_img_numpy=original_img_numpy/original_img_numpy.sum()
    sr_img_numpy =sr_img_numpy/sr_img_numpy.sum() 
    
    # 显示模糊图像
    im0=axes[i, 0].imshow(blurry_img_numpy)
    axes[i, 0].set_title('Blurry Image')
    axes[i, 0].axis('off')

    # 显示超分辨率图像
    im1=axes[i, 1].imshow(sr_img_numpy)
    axes[i, 1].set_title('SR Image')
    axes[i, 1].axis('off')
    
    # 显示原始图像
    im2=axes[i, 2].imshow(original_img_numpy)
    axes[i, 2].set_title('Original Image')
    axes[i, 2].axis('off')


    
    # res_blur
    res_blur = (blurry_img_numpy-original_img_numpy)
    res_sr = (sr_img_numpy-original_img_numpy)
    vmin = min(res_blur.min(),res_sr.min())
    vmax = max(res_blur.max(),res_sr.max())
    im3= axes[i, 3].imshow(res_blur,vmin =vmin,vmax=vmax)
    axes[i, 3].set_title('Res Blur')
    axes[i, 3].axis('off')

    # res_sr
    im4 = axes[i, 4].imshow(res_sr,vmin =vmin,vmax=vmax)
    axes[i, 4].set_title('Res SR')
    axes[i, 4].axis('off')
    cbar2 = fig.colorbar(
        im4, ax=axes[i,4],shrink = 0.5
    )

# 调整子图之间的间距
plt.tight_layout()

# 显示图像
plt.show()
